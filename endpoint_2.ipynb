# %%
import pandas as pd

# %%
data_geme = pd.read_parquet("video_games_recommend\dataSet\steam_game_clean.parquet")

# %%
data_item = pd.read_parquet("video_games_recommend/dataSet/user_items_clean.parquet")

# %%
data_review = pd.read_parquet("video_games_recommend/dataSet/user_review_clean.parquet")

# %%
data_review.head(4)
# Out:
#   item_id  feeling_negative  feeling_positive  feeling_neutral
# 0      10                 2                34               20
# 1   10090                 6                39                6
# 2   10130                 0                 2                0
# 3   10140                 1                 0                0

# %%
data_item.head(4)
# Out:
#   item_id              item_name  playtime_forever           steam_id  \
# 0      10         Counter-Strike                 6  76561197970982479
# 1      20  Team Fortress Classic                 0  76561197970982479
# 2      30          Day of Defeat                 7  76561197970982479
# 3      40     Deathmatch Classic                 0  76561197970982479
#
#    items_count            user_id  \
# 0          277  76561197970982479
# 1          277  76561197970982479
# 2          277  76561197970982479
# 3          277  76561197970982479
#
#                                             user_url
# 0  http://steamcommunity.com/profiles/76561197970...
# 1  http://steamcommunity.com/profiles/76561197970...
# 2  http://steamcommunity.com/profiles/76561197970...
# 3  http://steamcommunity.com/profiles/76561197970...

# %%
data_geme.head(4)
# Out:
#                                   publisher     genres  \
# 0                                 Available      Indie
# 1               Rocketeer Games Studio, LLC     Action
# 2                                  Red Beat      Indie
# 3  LucasArts, Lucasfilm, Disney Interactive  Adventure
#
#                                             app_name  \
# 0  Fantasy Grounds - Top-Down Tokens - Darkwoulfe...
# 1                            Red Crucible®: Reloaded
# 2                                        Space Rogue
# 3           Indiana Jones® and the Fate of Atlantis™
#
#                                                title  price  early_access  \
# 0  Fantasy Grounds - Top-Down Tokens - Darkwoulfe...   4.99         False
# 1                            Red Crucible®: Reloaded   0.00         False
# 2                                        Space Rogue   9.99         False
# 3           Indiana Jones® and the Fate of Atlantis™   5.99         False
#
# ...

# %%
import pandas as pd
import gzip as gzip
import ast
import json

# %%
archivo = "../dataSet/steam_games.json.gz"

data = []

with gzip.open(archivo, 'rt', encoding='utf-8') as file:
    for line in file:
        try:
            cleaned_line = line.replace('NaN', 'null')
            json_data = json.loads(cleaned_line)
            data.append(json_data)
        except json.JSONDecodeError as e:
            print(f"Error en la línea: {line}")
            print(f"Detalle del error: {e}")
            continue

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   publisher genres app_name title   url release_date  tags reviews_url specs  \
# 0      None   None     None  None  None         None  None        None  None
# 1      None   None     None  None  None         None  None        None  None
# 2      None   None     None  None  None         None  None        None  None
# 3      None   None     None  None  None         None  None        None  None
# 4      None   None     None  None  None         None  None        None  None
#
#   price early_access    id developer
# 0  None         None  None      None
# 1  None         None  None      None
# 2  None         None  None      None
# 3  None         None  None      None
# 4  None         None  None      None

# %%
df.shape
# Out:
# (120445, 13)

# %%
df.head()
# Out:
#   publisher genres app_name title   url release_date  tags reviews_url specs  \
# 0      None   None     None  None  None         None  None        None  None
# 1      None   None     None  None  None         None  None        None  None
# 2      None   None     None  None  None         None  None        None  None
# 3      None   None     None  None  None         None  None        None  None
# 4      None   None     None  None  None         None  None        None  None
#
#   price early_access    id developer
# 0  None         None  None      None
# 1  None         None  None      None
# 2  None         None  None      None
# 3  None         None  None      None
# 4  None         None  None      None

# %%
df_steam_games = df.dropna(how='all')

# %%
# determinar el tamaño del dataframe, muestra que es de 32135 filas y 13 columnas
df_steam_games.shape
# Out:
# (32135, 13)

# %%
df_steam_games.head()
# Out:
#               publisher                                             genres  \
# 88310         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313              彼岸领域                        [Action, Adventure, Casual]
# 88314              None                                               None
#
#                       app_name                    title  \
# 88310      Lost Summoner Kitty      Lost Summoner Kitty
# 88311                Ironbound                Ironbound
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 88313                  弹炸人2222                  弹炸人2222
# 88314            Log Challenge                     None
#
#                                                      url release_date  \
# 88310  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# ...

# %%
#identificamos los valores unicos de la columna price
df_steam_games['price'].unique()
# Out:
# array([4.99, 'Free To Play', 'Free to Play', 0.99, 2.99, 3.99, 9.99,
#        18.99, 29.99, None, 'Free', 10.99, 1.59, 14.99, 1.99, 59.99, 8.99,
#        6.99, 7.99, 39.99, 19.99, 7.49, 12.99, 5.99, 2.49, 15.99, 1.25,
#        24.99, 17.99, 61.99, 3.49, 11.99, 13.99, 'Free Demo',
#        'Play for Free!', 34.99, 74.76, 1.49, 32.99, 99.99, 14.95, 69.99,
#        16.99, 79.99, 49.99, 5.0, 44.99, 13.98, 29.96, 119.99, 109.99,
#        149.99, 771.71, 'Install Now', 21.99, 89.99,
#        'Play WARMACHINE: Tactics Demo', 0.98, 139.92, 4.29, 64.99,
#        'Free Mod', 54.99, 74.99, 'Install Theme', 0.89, 'Third-party',
#        0.5, 'Play Now', 299.99, 1.29, 3.0, 15.0, 5.49, 23.99, 49.0, 20.99,
#        10.93, 1.39, 'Free HITMAN™ Holiday Pack', 36.99, 4.49, 2.0, 4.0,
#        9.0, 234.99, 1.95, 1.5, 199.0, 189.0, 6.66, 27.99, 10.49, 129.99,
#        179.0, 26.99, 399.99, 31.99, 399.0, 20.0, 40.0, 3.33, 199.99,
#        22.99, 320.0, 38.85, 71.7, 59.95, 995.0, 27.49, 3.39, 6.0, 19.95,
# ...

# %%
df_steam_games['price'] = df_steam_games['price'].replace({ 'Starting at $499.00': 499.0})
df_steam_games['price'] = df_steam_games['price'].replace({ 'Starting at $449.00': 449.0})
# Out:
# C:\Users\BORDADO Y ESTAMPADO\AppData\Local\Temp\ipykernel_27872\1120345344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_steam_games['price'] = df_steam_games['price'].replace({ 'Starting at $499.00': 499.0})
# C:\Users\BORDADO Y ESTAMPADO\AppData\Local\Temp\ipykernel_27872\1120345344.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_steam_games['price'] = df_steam_games['price'].replace({ 'Starting at $449.00': 449.0})

# %%
# Convertir valores no numéricos a NaN
df_steam_games['price'] = pd.to_numeric(df_steam_games['price'], errors='coerce')

# Reemplazar NaN con 0.0
df_steam_games['price'].fillna(0.0, inplace=True)

# Verificar los cambios
df_steam_games.head()
# Out:
# C:\Users\BORDADO Y ESTAMPADO\AppData\Local\Temp\ipykernel_27872\485868949.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_steam_games['price'] = pd.to_numeric(df_steam_games['price'], errors='coerce')
# C:\Users\BORDADO Y ESTAMPADO\AppData\Local\Temp\ipykernel_27872\485868949.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df_steam_games['price'].dtype
# Out:
# dtype('float64')

# %%
#1. identificar los registros duplicados que tiene la columna id
duplicated_ids = df_steam_games[df_steam_games.duplicated('id', keep=False)]

#2. #1. mostrar los registros duplicados que tiene la columna id
duplicated_ids
# Out:
#                                                 publisher  \
# 88384                                                None
# 102204                                 Bethesda Softworks
# 102883                                 Bethesda Softworks
# 119271  Warner Bros. Interactive Entertainment, Feral ...
#
#                      genres                                        app_name  \
# 88384                  None                                            None
# 102204             [Action]                Wolfenstein II: The New Colossus
# 102883             [Action]                Wolfenstein II: The New Colossus
# 119271  [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
#
#                                                  title  \
# 88384                                             None
# 102204                Wolfenstein II: The New Colossus
# 102883                Wolfenstein II: The New Colossus
# 119271  Batman: Arkham City - Game of the Year Edition
#
# ...

# %%
# Eliminar duplicados, manteniendo solo la primera aparición en la columna id

#Crear máscara booleana para excluir el primer duplicado (NaN)
mascara_bool = ~df_steam_games.index.isin([duplicated_ids])

#Seleccionar filas con la máscara
df_new = df_steam_games[mascara_bool]

#Reemplazar df_steam_games con solo valores verdaderos de la máscara
df_steam_games = df_new.copy()

#se corrobora que se elimina el registro
filtered_rows = df_steam_games[df_steam_games['id'].isna()]
filtered_rows
# Out:
#                                                 publisher  \
# 88384                                                None
# 119271  Warner Bros. Interactive Entertainment, Feral ...
#
#                      genres                                        app_name  \
# 88384                  None                                            None
# 119271  [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
#
#                                                  title  \
# 88384                                             None
# 119271  Batman: Arkham City - Game of the Year Edition
#
#                                              url release_date  \
# 88384             http://store.steampowered.com/         None
# 119271  http://store.steampowered.com/app/200260   2012-09-07
#
#                                                      tags reviews_url  \
# 88384                                                None        None
# ...

# %%
df_steam_games['release_date'].isna().value_counts()
# Out:
# release_date
# False    30068
# True      2067
# Name: count, dtype: int64

# %%
# Eliminar las filas donde 'release_date' es None o NaN
df_steam_games = df_steam_games.dropna(subset=['release_date'])

# %%
df_steam_games['release_date'].isna().value_counts()
# Out:
# release_date
# False    30068
# Name: count, dtype: int64

# %%
# Convertir la columna 'release_date' a datetime, convirtiendo errores a NaT
df_steam_games['release_date'] = pd.to_datetime(df_steam_games['release_date'], errors='coerce')

# %%
#Eliminar filas con NaT en 'release_date'
df_steam_games_cleaned = df_steam_games.dropna(subset=['release_date'])

# %%
# Asegurarse de que 'release_date' está en formato datetime
df_steam_games['release_date'] = pd.to_datetime(df_steam_games['release_date'])
df_steam_games['Year'] = df_steam_games['release_date'].dt.year
# Eliminar la columna 'release_date'
df_steam_games = df_steam_games.drop(columns=['release_date'])

# %%
df_steam_games.head()
# Out:
#                  publisher                                             genres  \
# 88310            Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311     Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312         Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                 彼岸领域                        [Action, Adventure, Casual]
# 88315  Trickjump Games Ltd                    [Action, Adventure, Simulation]
#
#                       app_name                    title  \
# 88310      Lost Summoner Kitty      Lost Summoner Kitty
# 88311                Ironbound                Ironbound
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 88313                  弹炸人2222                  弹炸人2222
# 88315    Battle Royale Trainer    Battle Royale Trainer
#
#                                                      url  \
# 88310  http://store.steampowered.com/app/761140/Lost_...
# ...

# %%
# Columnas que necesitan cambiar los valores nulos
columns_to_fill = ['publisher', 'app_name', 'title', 'developer']
# Reemplazar valores nulos con 'Available'
df_steam_games[columns_to_fill] = df_steam_games[columns_to_fill].fillna('Available')

# %%
df_steam_games
# Out:
#                   publisher  \
# 88310             Kotoshiro
# 88311      Making Fun, Inc.
# 88312          Poolians.com
# 88313                  彼岸领域
# 88315   Trickjump Games Ltd
# ...                     ...
# 120439      Bidoniera Games
# 120440      Ghost_RUS Games
# 120441               Sacada
# 120442         Laush Studio
# 120443             SIXNAILS
#
#                                                    genres  \
# 88310       [Action, Casual, Indie, Simulation, Strategy]
# 88311                [Free to Play, Indie, RPG, Strategy]
# 88312   [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                         [Action, Adventure, Casual]
# 88315                     [Action, Adventure, Simulation]
# ...                                                   ...
# 120439                 [Action, Adventure, Casual, Indie]
# 120440              [Casual, Indie, Simulation, Strategy]
# 120441                          [Casual, Indie, Strategy]
# ...

# %%
df_steam_games = df_steam_games.explode('genres')
df_steam_games = df_steam_games.dropna(subset=['genres'])
df_steam_games.head()
# Out:
#        publisher      genres             app_name                title  \
# 88310  Kotoshiro      Action  Lost Summoner Kitty  Lost Summoner Kitty
# 88310  Kotoshiro      Casual  Lost Summoner Kitty  Lost Summoner Kitty
# 88310  Kotoshiro       Indie  Lost Summoner Kitty  Lost Summoner Kitty
# 88310  Kotoshiro  Simulation  Lost Summoner Kitty  Lost Summoner Kitty
# 88310  Kotoshiro    Strategy  Lost Summoner Kitty  Lost Summoner Kitty
#
#                                                      url  \
# 88310  http://store.steampowered.com/app/761140/Lost_...
# 88310  http://store.steampowered.com/app/761140/Lost_...
# 88310  http://store.steampowered.com/app/761140/Lost_...
# 88310  http://store.steampowered.com/app/761140/Lost_...
# 88310  http://store.steampowered.com/app/761140/Lost_...
#
#                                                 tags  \
# 88310  [Strategy, Action, Indie, Casual, Simulation]
# 88310  [Strategy, Action, Indie, Casual, Simulation]
# ...

# %%
#se eliminan las columnas tags, specs, url y reviews_url al conciderarse que no son necesarias
df_steam_games = df_steam_games.drop(['tags', 'specs', 'url', 'reviews_url'], axis=1)

df_steam_games.columns
# Out:
# Index(['publisher', 'genres', 'app_name', 'title', 'price', 'early_access',
#        'id', 'developer', 'Year'],
#       dtype='object')

# %%
# Se verifica como quedan los tipos de datos y si hay nulo
df_steam_games.isna().value_counts()
# Out:
# publisher  genres  app_name  title  price  early_access  id     developer  Year
# False      False   False     False  False  False         False  False      False    70702
#                                                                            True       797
#                                                          True   False      False        2
# Name: count, dtype: int64

# %%
steam_game_clean = '../dataSet/steam_game_clean.parquet'
df_steam_games.to_parquet(steam_game_clean, index=False)
print(f'Se guardó el archivo {steam_game_clean}')
# Out:
# Se guardó el archivo ../dataSet/steam_game_clean.parquet
